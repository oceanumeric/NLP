# %% [markdown]
# # EPO Linked Data Query Practice
#
# We will go through a few examples of how to query the EPO Linked Data API. The examples are based on the [EPO Linked Data API documentation](https://data.epo.org/linked-data/sparql.htmll).

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON, XML, RDF, CSV, N3, TURTLE, TSV

# %%
# end point for EPO
sparql = SPARQLWrapper("https://data.epo.org/linked-data/query") #determine SPARQL endpoint
sparql.setReturnFormat(JSON) #determine the output format

# %%
# list of applications
sparql.setQuery("""
    prefix patent: <http://data.epo.org/linked-data/def/patent/>
    prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

    SELECT ?application ?appNum ?filingDate ?authority
    WHERE {
    # ?application rdf:type patent:Application ;
        patent:applicationNumber ?appNum ;
        patent:filingDate        ?filingDate ; 
        patent:applicationAuthority ?authority ;
        .
    } LIMIT 10
""")

results = sparql.query().convert()

# %%
results = pd.json_normalize(results['results']['bindings'])
results.head()
# Out:
#   application.type                                  application.value
# 0              uri  http://data.epo.org/linked-data/id/application...  \
# 1              uri  http://data.epo.org/linked-data/id/application...
# 2              uri  http://data.epo.org/linked-data/id/application...
# 3              uri  http://data.epo.org/linked-data/id/application...
# 4              uri  http://data.epo.org/linked-data/id/application...
#
#   appNum.type appNum.value filingDate.type
# 0     literal     92911263         literal  \
# 1     literal     69230802         literal
# 2     literal     51125992         literal
# 3     literal  1992FR00424         literal
# 4     literal      1908492         literal
#
#                      filingDate.datatype filingDate.value authority.type
# 0  http://www.w3.org/2001/XMLSchema#date       1992-05-14            uri  \
# 1  http://www.w3.org/2001/XMLSchema#date       1992-05-14            uri
# 2  http://www.w3.org/2001/XMLSchema#date       1992-05-14            uri
# 3  http://www.w3.org/2001/XMLSchema#date       1992-05-14            uri
# 4  http://www.w3.org/2001/XMLSchema#date       1992-05-14            uri
#
#                              authority.value
# 0  http://data.epo.org/linked-data/id/st3/AT
# 1  http://data.epo.org/linked-data/id/st3/DE
# 2  http://data.epo.org/linked-data/id/st3/JP
# 3  http://data.epo.org/linked-data/id/st3/WO
# 4  http://data.epo.org/linked-data/id/st3/AU

# %%
# only keep columns that names contains '.value'
results = results[results.columns[results.columns.str.contains('.value')]]
results.head()
# Out:
#                                    application.value appNum.value
# 0  http://data.epo.org/linked-data/id/application...     92911263  \
# 1  http://data.epo.org/linked-data/id/application...     69230802
# 2  http://data.epo.org/linked-data/id/application...     51125992
# 3  http://data.epo.org/linked-data/id/application...  1992FR00424
# 4  http://data.epo.org/linked-data/id/application...      1908492
#
#   filingDate.value                            authority.value
# 0       1992-05-14  http://data.epo.org/linked-data/id/st3/AT
# 1       1992-05-14  http://data.epo.org/linked-data/id/st3/DE
# 2       1992-05-14  http://data.epo.org/linked-data/id/st3/JP
# 3       1992-05-14  http://data.epo.org/linked-data/id/st3/WO
# 4       1992-05-14  http://data.epo.org/linked-data/id/st3/AU

# %%
print(results['application.value'].values)
# Out:
# ['http://data.epo.org/linked-data/id/application/AT/92911263T'
#  'http://data.epo.org/linked-data/id/application/DE/69230802T'
#  'http://data.epo.org/linked-data/id/application/JP/51125992'
#  'http://data.epo.org/linked-data/id/application/WO/1992FR00424'
#  'http://data.epo.org/linked-data/id/application/AU/1908492'
#  'http://data.epo.org/linked-data/id/application/US/14615493'
#  'http://data.epo.org/linked-data/id/application/FR/9105870'
#  'http://data.epo.org/linked-data/id/application/OA/60435'
#  'http://data.epo.org/linked-data/id/application/EP/92911263'
#  'http://data.epo.org/linked-data/id/application/WO/1992FR000424']

# %%
# words in abstract
sparql.setQuery("""
prefix patent: <http://data.epo.org/linked-data/def/patent/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix dcterms: <http://purl.org/dc/terms/>
prefix text: <http://jena.apache.org/text#>

SELECT DISTINCT ?publication ?application ?title ?publication_date ?abstract
WHERE {
  # ?publication text:query ( dcterms:abstract "battery" ) ;
               patent:titleOfInvention ?title ;
               patent:application ?application ;
               patent:publicationDate ?publication_date ;
               dcterms:abstract        ?abstract ; 
               .
} 
ORDER BY DESC(?publication_date)
LIMIT 100
""")

results = sparql.query().convert()

# %%
results = pd.json_normalize(results['results']['bindings'])
results = results[results.columns[results.columns.str.contains('.value')]]
results.head()
# Out:
#                                    publication.value
# 0  http://data.epo.org/linked-data/data/publicati...  \
# 1  http://data.epo.org/linked-data/data/publicati...
# 2  http://data.epo.org/linked-data/data/publicati...
# 3  http://data.epo.org/linked-data/data/publicati...
# 4  http://data.epo.org/linked-data/data/publicati...
#
#                                    application.value
# 0  http://data.epo.org/linked-data/id/application...  \
# 1  http://data.epo.org/linked-data/id/application...
# 2  http://data.epo.org/linked-data/id/application...
# 3  http://data.epo.org/linked-data/id/application...
# 4  http://data.epo.org/linked-data/id/application...
#
#                                          title.value publication_date.value
# 0  BATTERIEVERWALTUNGSVERFAHREN, SPEICHERSTEUERUN...             2024-03-20  \
# 1  BATTERY MANAGEMENT METHOD, STORAGE CONTROLLER,...             2024-03-20
# 2  PROCÉDÉ DE GESTION DE BATTERIE, CONTRÔLEUR DE ...             2024-03-20
# 3                 BATTERIEMODUL MIT EINER MITTELWAND             2024-03-20
# 4             BATTERY MODULE INCLUDING A CENTER WALL             2024-03-20
#
#                                       abstract.value
# 0  A battery management method according to one a...
# 1  A battery management method according to one a...
# 2  A battery management method according to one a...
# 3  A battery module includes: first and second su...
# 4  A battery module includes: first and second su...

# %%
# information about a specific application
sparql.setQuery("""
SELECT DISTINCT * 
WHERE {
   <http://data.epo.org/linked-data/id/application/EP/01903571> ?uri_key ?uri_content .
}
""")

results = sparql.query().convert()

# %%
results = pd.json_normalize(results['results']['bindings'])
results = results[results.columns[results.columns.str.contains('.value')]]

results
# Out:
#                                         uri_key.value
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 1   http://data.epo.org/linked-data/def/patent/app...
# 2   http://data.epo.org/linked-data/def/patent/app...
# 3   http://data.epo.org/linked-data/def/patent/fil...
# 4   http://data.epo.org/linked-data/def/patent/gra...
# 5   http://data.epo.org/linked-data/def/patent/app...
# 6   http://data.epo.org/linked-data/def/patent/app...
# 7   http://data.epo.org/linked-data/def/patent/pub...
# 8   http://data.epo.org/linked-data/def/patent/pub...
# 9   http://data.epo.org/linked-data/def/patent/app...
# 10  http://data.epo.org/linked-data/def/patent/cla...
# 11  http://data.epo.org/linked-data/def/patent/cla...
# 12  http://data.epo.org/linked-data/def/patent/cla...
#
#                                     uri_content.value
# 0   http://data.epo.org/linked-data/def/patent/App...
# 1           http://data.epo.org/linked-data/id/st3/EP
# 2                                            01903571
# 3                                          2001-01-20
# 4                                          2006-08-16
# 5                                       EP20010903571
# 6                                            01903571
# 7   http://data.epo.org/linked-data/data/publicati...
# 8   http://data.epo.org/linked-data/data/publicati...
# 9   http://data.epo.org/linked-data/def/patent/app...
# 10  http://data.epo.org/linked-data/def/cpc/H03L7-085
# 11  http://data.epo.org/linked-data/def/cpc/H04J3-076
# 12  http://data.epo.org/linked-data/def/cpc/H03L7-...

# %%
# information about a specific publication
sparql.setQuery("""
SELECT DISTINCT *
WHERE {
   <http://data.epo.org/linked-data/data/publication/EP/4339007/A1/-> ?title ?abstract .
}
""")
results = sparql.query().convert()

# %%
results = pd.json_normalize(results['results']['bindings'])
results = results[results.columns[results.columns.str.contains('.value')]]

# %%
results
# Out:
#                                           title.value
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 1          http://www.w3.org/2000/01/rdf-schema#label
# 2   http://data.epo.org/linked-data/def/patent/pub...
# 3   http://data.epo.org/linked-data/def/patent/pub...
# 4   http://data.epo.org/linked-data/def/patent/pub...
# 5   http://data.epo.org/linked-data/def/patent/pub...
# 6   http://data.epo.org/linked-data/def/patent/pub...
# 7                   http://purl.org/dc/terms/language
# 8   http://data.epo.org/linked-data/def/patent/age...
# 9   http://data.epo.org/linked-data/def/patent/app...
# 10  http://data.epo.org/linked-data/def/patent/inv...
# 11  http://data.epo.org/linked-data/def/patent/app...
# 12  http://data.epo.org/linked-data/def/patent/fil...
# 13  http://data.epo.org/linked-data/def/patent/pri...
# 14  http://data.epo.org/linked-data/def/patent/pro...
# 15  http://data.epo.org/linked-data/def/patent/rep...
# 16  http://data.epo.org/linked-data/def/patent/rep...
# 17  http://data.epo.org/linked-data/def/patent/rep...
# 18  http://data.epo.org/linked-data/def/patent/tit...
# 19  http://data.epo.org/linked-data/def/patent/tit...
# 20  http://data.epo.org/linked-data/def/patent/tit...
# 21                  http://purl.org/dc/terms/abstract
# 22  http://data.epo.org/linked-data/def/patent/cla...
# 23  http://data.epo.org/linked-data/def/patent/cla...
# 24  http://data.epo.org/linked-data/def/patent/cla...
# 25  http://data.epo.org/linked-data/def/patent/cla...
# 26  http://data.epo.org/linked-data/def/patent/cla...
#
#                                        abstract.value
# 0   http://data.epo.org/linked-data/def/patent/Pub...
# 1                                       EP 4339007 A1
# 2           http://data.epo.org/linked-data/id/st3/EP
# 3                                          2024-03-20
# 4   http://data.epo.org/linked-data/def/patent/pub...
# 5                         EUROPEAN PATENT APPLICATION
# 6                                             4339007
# 7            http://id.loc.gov/vocabulary/iso639-1/en
# 8   http://data.epo.org/linked-data/data/vc/AC646E...
# 9   http://data.epo.org/linked-data/data/vc/DD83CB...
# 10  http://data.epo.org/linked-data/data/vc/A530F1...
# 11  http://data.epo.org/linked-data/id/application...
# 12           http://id.loc.gov/vocabulary/iso639-1/en
# 13  http://data.epo.org/linked-data/id/application...
# 14           http://id.loc.gov/vocabulary/iso639-1/en
# 15  https://data.epo.org/linked-data/representatio...
# 16  https://data.epo.org/linked-data/representatio...
# 17  https://data.epo.org/linked-data/representatio...
# 18  BATTERY MANAGEMENT METHOD, STORAGE CONTROLLER,...
# 19  BATTERIEVERWALTUNGSVERFAHREN, SPEICHERSTEUERUN...
# 20  PROCÉDÉ DE GESTION DE BATTERIE, CONTRÔLEUR DE ...
# 21  A battery management method according to one a...
# 22   http://data.epo.org/linked-data/def/ipc/B60L3-12
# 23  http://data.epo.org/linked-data/def/ipc/B60L53-80
# 24  http://data.epo.org/linked-data/def/ipc/B60L53-10
# 25  http://data.epo.org/linked-data/def/ipc/B60L58-16
# 26  http://data.epo.org/linked-data/def/ipc/B60L53-68
